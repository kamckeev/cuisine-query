# %%
from math import pi
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum

# %%
filename = Path("cuisine_brief_json.json") # agnostic path using pathlib

df = pd.read_json(filename) # read in dataframe from file

# %%
# df_dict=df.to_dict()
# df_dict
df=df.T
# Out:
#               avocado  baking soda  black beans  black pepper  brown sugar  \
# french            NaN          NaN          NaN           NaN          NaN
# brazilian         NaN          NaN          NaN           NaN          NaN
# mexican        1572.0          NaN       1182.0           NaN          NaN
# greek             NaN          NaN          NaN           NaN          NaN
# moroccan          NaN          NaN          NaN           NaN          NaN
# vietnamese        NaN          NaN          NaN           NaN          NaN
# southern_us       NaN          NaN          NaN           NaN          NaN
# cajun_creole      NaN          NaN          NaN           NaN          NaN
# russian           NaN          NaN          NaN           NaN          NaN
# irish             NaN        156.0          NaN           NaN          NaN
# indian            NaN          NaN          NaN           NaN          NaN
# italian           NaN          NaN          NaN           NaN          NaN
# chinese           NaN          NaN          NaN           NaN        354.0
# jamaican          NaN          NaN          NaN         150.0          NaN
# japanese          NaN          NaN          NaN           NaN          NaN
# thai              NaN          NaN          NaN           NaN          NaN
# british           NaN          NaN          NaN           NaN          NaN
# korean            NaN          NaN          NaN           NaN          NaN
# spanish           NaN          NaN          NaN           NaN          NaN
# filipino          NaN          NaN          NaN           NaN          NaN
#
#               chicken broth  curry powder  dried thyme   eggs  feta cheese  \
# french                  NaN           NaN          NaN    NaN          NaN
# brazilian               NaN           NaN          NaN   96.0          NaN
# mexican                 NaN           NaN          NaN    NaN          NaN
# greek                   NaN           NaN          NaN    NaN        180.0
# moroccan                NaN           NaN          NaN    NaN          NaN
# vietnamese              NaN           NaN          NaN    NaN          NaN
# southern_us             NaN           NaN          NaN  972.0          NaN
# cajun_creole          264.0           NaN        258.0    NaN          NaN
# russian                 NaN           NaN          NaN  174.0          NaN
# irish                   NaN           NaN          NaN  138.0          NaN
# indian                  NaN         510.0          NaN    NaN          NaN
# italian                 NaN           NaN          NaN    NaN          NaN
# chinese                 NaN           NaN          NaN  420.0          NaN
# jamaican                NaN           NaN          NaN    NaN          NaN
# japanese                NaN           NaN          NaN    NaN          NaN
# thai                    NaN           NaN          NaN    NaN          NaN
# british                 NaN           NaN          NaN  294.0          NaN
# korean                  NaN           NaN          NaN  168.0          NaN
# spanish                 NaN           NaN          NaN    NaN          NaN
# filipino                NaN           NaN          NaN  174.0          NaN
#
#                ...    pepper  potatoes   sake  sesame seeds  soy sauce  \
# french         ...       NaN       NaN    NaN           NaN        NaN
# brazilian      ...       NaN       NaN    NaN           NaN        NaN
# mexican        ...    1152.0       NaN    NaN           NaN        NaN
# greek          ...     306.0       NaN    NaN           NaN        NaN
# moroccan       ...       NaN       NaN    NaN           NaN        NaN
# vietnamese     ...       NaN       NaN    NaN           NaN      234.0
# southern_us    ...     888.0       NaN    NaN           NaN        NaN
# cajun_creole   ...       NaN       NaN    NaN           NaN        NaN
# russian        ...       NaN       NaN    NaN           NaN        NaN
# irish          ...       NaN     126.0    NaN           NaN        NaN
# indian         ...       NaN       NaN    NaN           NaN        NaN
# italian        ...    1194.0       NaN    NaN           NaN        NaN
# chinese        ...       NaN       NaN    NaN           NaN     1944.0
# jamaican       ...     138.0       NaN    NaN           NaN      126.0
# japanese       ...       NaN       NaN  372.0           NaN      690.0
# thai           ...       NaN       NaN    NaN           NaN      486.0
# british        ...     150.0       NaN    NaN           NaN        NaN
# korean         ...       NaN       NaN    NaN         210.0      720.0
# spanish        ...       NaN       NaN    NaN           NaN        NaN
# filipino       ...     192.0       NaN    NaN           NaN      384.0
#
#                sugar  tomatoes  tumeric  unsalted butter   water
# french         972.0       NaN      NaN            534.0   504.0
# brazilian      132.0     114.0      NaN              NaN   114.0
# mexican          NaN    1350.0      NaN              NaN     NaN
# greek            NaN     240.0      NaN              NaN     NaN
# moroccan         NaN       NaN    162.0              NaN   156.0
# vietnamese     426.0       NaN      NaN              NaN   246.0
# southern_us   1572.0       NaN      NaN              NaN   864.0
# cajun_creole     NaN       NaN      NaN              NaN   336.0
# russian        240.0       NaN      NaN              NaN   156.0
# irish          180.0       NaN      NaN              NaN   132.0
# indian           NaN     738.0    630.0              NaN  1002.0
# italian       1164.0       NaN      NaN              NaN  1254.0
# chinese       1182.0       NaN      NaN              NaN   864.0
# jamaican       138.0       NaN      NaN              NaN   174.0
# japanese       582.0       NaN      NaN              NaN   426.0
# thai           480.0       NaN      NaN              NaN   306.0
# british        294.0       NaN      NaN            132.0     NaN
# korean         390.0       NaN      NaN              NaN   222.0
# spanish        240.0     162.0      NaN              NaN   180.0
# filipino       228.0       NaN      NaN              NaN   348.0
#
# [20 rows x 33 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-3984d209759d> in <module>()
#       1
# ----> 2 df.plot.bar(x=df.iloc[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwds)
#    3088             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3089         """
# -> 3090         return self(kind='bar', x=x, y=y, **kwds)
#    3091
#    3092     def barh(self, x=None, y=None, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1764                 if is_integer(x) and not data.columns.holds_integer():
#    1765                     x = data_cols[x]
# -> 1766                 elif not isinstance(data[x], ABCSeries):
#    1767                     raise ValueError("x must be a label or position")
#    1768                 data = data.set_index(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: '[ nan  nan  nan  nan  nan  nan  nan  nan  nan 156.  nan  nan  nan  nan\n  nan  nan  nan  nan  nan  nan] not in index'

# %%
country_data = df["cuisine"]
ingred_data = df.iloc[:,2:]

#cuisine_loc = country_data.str.match("filipino")
#print(cuisine_loc)
#select data for a single cuisine, can be looped later
this_cuisine = country_data.iloc[1]
this_data = ingred_data.iloc[1]

#print(this_data)
#create subset of largest used ingredients
subset = this_data.nlargest(5)
# total = this_data.sum() # total count
# misc_data = pd.Series([total - subset.sum()], index = ["misc"]) # get count of remaining ingredients
# subset = subset.append(misc_data)

#print(subset)
# colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
# explode = (0.1, 0, 0, 0, 0)  
plt.pie(subset,labels = subset.index, autopct='%1.1f%%', shadow=True, startangle=140)
# plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
plt.title(f'Top Five ingredients in {this_cuisine} recipes')
plt.show()

# %%
country_data = df["cuisine"]
ingred_data = df.iloc[:,2:]

this_cuisine = country_data.iloc[12]
this_data = ingred_data.iloc[12]

subset = this_data.nlargest(7)
plt.pie(subset,labels = subset.index, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title(f'Top Five ingredients in {this_cuisine} recipes')
plt.show()
