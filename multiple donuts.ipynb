# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
df=pd.read_csv("test.csv", index_col=0)
df.head()
# Out:
#               sugar  eggs  milk  pepper  unsalted butter  water  fish sauce  \
# cuisine
# brazilian        22    16     0       0                0     19           0
# british          49    49    39      25               22      0           0
# cajun_creole      0     0     0       0                0     56           0
# chinese         197    70     0       0                0    144           0
# filipino         38    29     0      32                0     58           0
#
#               soy sauce  kosher salt  olive oil      ...       avocado  \
# cuisine                                              ...
# brazilian             0            0          0      ...             0
# british               0            0          0      ...             0
# cajun_creole          0            0         52      ...             0
# chinese             324            0          0      ...             0
# filipino             64            0          0      ...             0
#
#               black beans  sesame seeds  fresh dill  baking soda  potatoes  \
# cuisine
# brazilian               0             0           0            0         0
# british                 0             0           0            0         0
# cajun_creole            0             0           0            0         0
# chinese                 0             0           0            0         0
# filipino                0             0           0            0         0
#
#               sake  mirin  lime juice  black pepper
# cuisine
# brazilian        0      0           0             0
# british          0      0           0             0
# cajun_creole     0      0           0             0
# chinese          0      0           0             0
# filipino         0      0           0             0
#
# [5 rows x 33 columns]

# %%
plt.figure(figsize=(15,10))
df.plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Country of Origin")
plt.ylabel("Highest point of Wines")
plt.show()
